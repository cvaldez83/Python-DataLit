# %% [markdown]
# <a href="https://colab.research.google.com/github/cvaldez83/Python-DataLit/blob/master/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# Out:
# ...
#     100% |████████████████████████████████| 133kB 3.9MB/s
# ...

# %%
#Step 2 - Import dependencies

import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
#Step 3 - My Twitter API Authentication Variables

consumer_key = '7jOdr1B7GMCBkqQHIfTZ9V4xv'
consumer_secret = 'ScXHqG2SzzOP4pTQYJ1fUKmey75XcbD5YLs8h6Lh8Ij1CtYikF'
access_token = '1927369406-4AO9j4NkXRqDeb82XPnM0eIcpbpMQeDqul2T7vi'
access_token_secret = '0gmn2GedoRUt0xplzXhfguen3TGsnR1zSqKYYDXUPSpEG'

# %%
#Step 4 - Authenticate

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %%
#Step 5 - Define Cleaning Function

import re

def clean_tweet(tweet):
  '''
  Utility function to clean the text in a tweet by 
  removing links and special characters using regex
  '''
  return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",tweet).split())

# %%
#Step 6 - Find Related Tweets

tweets = api.search('Apple Watch', count=200)

#We create a clean pandas datafram as follows:
data = pd.DataFrame(data=[clean_tweet(tweet.text) for tweet in tweets], columns=['Tweets'])
#data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

#We display the first 10 elements of the dataframe:
display(data.head(10))

#Meta data from a single tweet
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
# Out:
#                                               Tweets
# 0  andesign I see that you have realized one for ...
# 1                                    RT Apple iPhone
# 2                                    RT Apple iPhone
# 3                                    RT Apple iPhone
# 4                                    RT Apple iPhone
# 5  Sign up today and receive a FREE Spot2fish Fis...
# 6  RT In the 1990s I was mocking the idea of Body...
# 7                                    RT Apple iPhone
# 8                                    RT Apple iPhone
# 9       But you still gone keep your Apple Watch tho
# 1093517430775787525
# 2019-02-07 14:30:46
# Twitter for iPhone
# 0
# 0
# None
# None

# %%
#gather lexicon data

# !pip install nltk
import nltk
nltk.download('vader_lexicon')
# Out:
# ...
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
#Step 7 - Go through the tweets to analyze their sentiment

sid = SentimentIntensityAnalyzer()

listy = []
for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

#We display the first 100 elements of the dataframe:
display(data.head(100))
# Out:
#                                                Tweets  \
# 0   andesign I see that you have realized one for ...
# 1                                     RT Apple iPhone
# 2                                     RT Apple iPhone
# 3                                     RT Apple iPhone
# 4                                     RT Apple iPhone
# 5   Sign up today and receive a FREE Spot2fish Fis...
# 6   RT In the 1990s I was mocking the idea of Body...
# 7                                     RT Apple iPhone
# 8                                     RT Apple iPhone
# 9        But you still gone keep your Apple Watch tho
# 10                                    RT Apple iPhone
# 11                                    RT Apple iPhone
# 12                                    RT Apple iPhone
# 13                                    RT Apple iPhone
# 14  RT New visuals from Watch the KidsTurnedOutFin...
# 15  I love that the Apple Watch creates challenges...
# ...
